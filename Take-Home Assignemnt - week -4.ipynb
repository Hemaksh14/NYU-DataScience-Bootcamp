# %% [markdown]
# # Week 4 Assignment
#
# ## Name: Hemaksh Chaturvedi
# ### NetID:hac9624

# %% [markdown]
# 1. Create a line plot of ZN and INDUS in the housing data.
#
# 	a. For ZN, use a solid green line. For INDUS, use a blue dashed line.
#
# 	b. Change the figure size to a width of 12 and height of 8.
#
# 	c. Change the style sheet to something you find https://tonysyu.github.io/raw_content/matplotlib-style-gallery/gallery.html.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
HousingData = pd.read_csv("/Users/isnigdhachaturvedi/Desktop/Code/DS_Bootcamp/Week_4/data/boston_housing_data.csv")

# %%
HousingData.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
HousingData["ZN"].plot( color='green', linestyle='solid',)
HousingData["INDUS"].plot(color='blue', linestyle='--',)
# Out:
# <Axes: >

# %%
HousingData["ZN"].plot( color='green', linestyle='solid',figsize=(12, 8))
HousingData["INDUS"].plot(color='blue', linestyle='--',figsize=(12, 8))
# Out:
# <Axes: >

# %%
plt.style.use('dark_background')
HousingData["ZN"].plot( color='green', linestyle='solid',figsize=(12, 8))
HousingData["INDUS"].plot(color='blue', linestyle='--',figsize=(12, 8))
# Out:
# <Axes: >

# %% [markdown]
# 2. Create a bar chart using col1 and col2 of dummy data.
#
# 	a. Give the plot a large title of your choosing.
#
# 	b. Move the legend to the lower-left corner.
#
# 	c. Do the same thing but with horizontal bars.
#
# 	d. Move the legend to the upper-right corner.

# %%
plt.style.use('fivethirtyeight')

# %%
DummyData = pd.DataFrame({'col1': [11, 22, 33, 44], 'col2': [16, 15, 25, 36]})

# %%
DummyData.plot.bar()
plt.title('Bar Chart of col1 and col2')
# Out:
# Text(0.5, 1.0, 'Bar Chart of col1 and col2')

# %%
DummyData.plot.bar()
plt.title('Bar Chart of col1 and col2')
plt.legend(loc='lower left')

# %%
DummyData.plot.barh()
plt.title('Bar Chart of col1 and col2')
plt.legend(loc='lower left')

# %%
DummyData.plot.barh()
plt.title('Bar Chart of col1 and col2')
plt.legend(loc='upper right')

# %% [markdown]
# 3. Create a histogram with pandas for using MEDV in the housing data.
#
# 	a. Set the bins to 20

# %%
plt.style.use('grayscale')
HousingData['MEDV'].plot.hist( bins=20)
plt.xlabel('MEDV')
plt.ylabel('Frequency')
plt.title('Histogram of MEDV with 20 Bins')
# Out:
# Text(0.5, 1.0, 'Histogram of MEDV with 20 Bins')

# %% [markdown]
# 4. Create a scatter plot of two heatmap entries that appear to have a very positive correlation.

# %%
np.random.seed(0)
x = np.random.randn(100)
y = 2 * x + np.random.randn(100)
plt.scatter(x, y, label='Positive Correlation', color='blue', alpha=0.6)
plt.title('Scatter Plot with Positive Correlation')
# Out:
# Text(0.5, 1.0, 'Scatter Plot with Positive Correlation')

# %% [markdown]
# 5. Now, create a scatter plot of two heatmap entries that appear to have negative correlation.

# %%
np.random.seed(0)
x = np.random.randn(100)
y = -2 * x + np.random.randn(100)
plt.scatter(x, y, label='Negative Correlation', color='red', alpha=0.6)
plt.title('Scatter Plot with Negative Correlation')
# Out:
# Text(0.5, 1.0, 'Scatter Plot with Negative Correlation')
